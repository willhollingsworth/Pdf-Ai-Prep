# %%
# Files
from main import add_footer_to_pdf, merge_pdfs_with_bookmarks, process_pdfs, process_folder

input_pdf = "example 1.pdf"
output_pdf = "output.pdf"

input_pdfs = ["example 1.pdf", "example 2.pdf"]
output_combined_pdf = "combined_output.pdf"

# %%
add_footer_to_pdf(input_pdf, output_pdf)
# Out:
# Adding footer to 'example 1.pdf' with 2 pages

# %%
merge_pdfs_with_bookmarks(input_pdfs, output_pdf)
# Out:
# Merging ['example 1.pdf', 'example 2.pdf'] to single PDF : output.pdf

# %%
process_pdfs(input_pdfs, output_combined_pdf)
# Out:
# Adding footers
# Adding footer to 'example 1.pdf' with 2 pages
# Stamped example 1.pdf
# Adding footer to 'example 2.pdf' with 2 pages
# Stamped example 2.pdf
# Merging 2 PDFs
# Merging ['stamped_example 1.pdf', 'stamped_example 2.pdf'] to single PDF : combined_output.pdf
# Created: combined_output.pdf
# Cleaning up temp stamp files
# Complete!

# %%
cli_command = "main.py ."
setup_command = "uv run "
import subprocess
from pathlib import Path
result = subprocess.run(
    setup_command + cli_command, capture_output=True, text=True
)
print(result.stdout.strip())
# Out:
# Processing folder: . with pdf count 2 files
# Adding footers
# Adding footer to 'example 1.pdf' with 2 pages
# Stamped example 1.pdf
# Adding footer to 'example 2.pdf' with 2 pages
# Stamped example 2.pdf
# Merging 2 PDFs
# Merging ['stamped_example 1.pdf', 'stamped_example 2.pdf'] to single PDF : _combined.pdf
# Created: _combined.pdf
# Cleaning up temp stamp files
# Complete!
